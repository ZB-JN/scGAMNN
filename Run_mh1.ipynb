# %%
# %load_ext memory_profiler
import os
import tensorflow as tf
import warnings
import numpy as np
import pandas as pd
import scanpy as sc

warnings.simplefilter(action='ignore', category=FutureWarning)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

from scgamnn import scGAMNN
from utils import *
from metrics import *
warnings.filterwarnings("ignore")

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=100)
sc.settings.set_figure_params(dpi_save=300)
sc.logging.print_version_and_date()

adata1  = sc.read_csv("E:/scGAMNN/data/mh1/Data1.csv")
adata2 = sc.read_csv("E:/scGAMNN/data/mh1/Data2.csv")
adata = adata1.concatenate(adata2)
ident1 = pd.read_csv("E:/scGAMNN/data/mh1/label1.csv")
ident2 = pd.read_csv("E:/scGAMNN/data/mh1/label2.csv")
idents = np.vstack((ident1, ident2))
adata.obs['celltype'] = idents
match = np.array(pd.read_csv("E:/scGAMNN/data/mh1/match.csv"))
adata.obs["batch"] = np.array([0] * len(ident1) + [1] * len(ident2))
sc.pp.normalize_per_cell(adata)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, n_top_genes=2000, flavor='seurat_v3',batch_key='batch')
adata = adata[:,adata.var['highly_variable']]
sc.pp.scale(adata, max_value=10)
adatas = [adata[adata.obs['batch'] == i, :].copy() for i in [0,1]]
scaledata = adata.X
adj, adj_n = construct_graph(adatas, match)
# Out:
# Running Scanpy 1.9.1, on 2023-07-14 09:41.
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)

# %%
model = scGAMNN(scaledata, adj, adj_n, match=match,hidden_dim=120, latent_dim=50, decA="DBL", layer_enc="GCN")

import time
time_s = time.time()
# %memit model.train(epochs=200, W_a=1, W_x=1, W_w=0.05)
print('time used:', time.time()-time_s)
# Out:
# Epoch 1  X_rec_loss: 0.7640984   A_rec_loss: 0.3074823   MNN_loss: 0.3074823  total_loss:  1.1886683
# Learning rate = 0.0020000
# Epoch 2  X_rec_loss: 0.75717473   A_rec_loss: 0.04797626   MNN_loss: 0.04797626  total_loss:  0.9174265
# Learning rate = 0.0020000
# Epoch 3  X_rec_loss: 0.74996215   A_rec_loss: 0.069423996   MNN_loss: 0.069423996  total_loss:  0.9419442
# Learning rate = 0.0020000
# Epoch 4  X_rec_loss: 0.73693854   A_rec_loss: 0.0021887466   MNN_loss: 0.0021887466  total_loss:  0.8660734
# Learning rate = 0.0020000
# Epoch 5  X_rec_loss: 0.72265226   A_rec_loss: 0.00093282986   MNN_loss: 0.00093282986  total_loss:  0.85389996
# Learning rate = 0.0020000
# Epoch 6  X_rec_loss: 0.70982003   A_rec_loss: 0.00084770087   MNN_loss: 0.00084770087  total_loss:  0.84439087
# Learning rate = 0.0020000
# Epoch 7  X_rec_loss: 0.6945569   A_rec_loss: 0.0008461833   MNN_loss: 0.0008461833  total_loss:  0.83205545
# Learning rate = 0.0020000
# Epoch 8  X_rec_loss: 0.6893273   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.8288082
# Learning rate = 0.0020000
# Epoch 9  X_rec_loss: 0.6834549   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.82360005
# Learning rate = 0.0020000
# Epoch 10  X_rec_loss: 0.67707807   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.8163533
# Learning rate = 0.0020000
# Epoch 11  X_rec_loss: 0.67032593   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.80738604
# Learning rate = 0.0020000
# Epoch 12  X_rec_loss: 0.665716   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.79998195
# Learning rate = 0.0020000
# Epoch 13  X_rec_loss: 0.6609111   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7923684
# Learning rate = 0.0020000
# Epoch 14  X_rec_loss: 0.6570546   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7857108
# Learning rate = 0.0020000
# Epoch 15  X_rec_loss: 0.6534165   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7789528
# Learning rate = 0.0020000
# Epoch 16  X_rec_loss: 0.65016896   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7721842
# Learning rate = 0.0020000
# Epoch 17  X_rec_loss: 0.6471546   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.76545966
# Learning rate = 0.0020000
# Epoch 18  X_rec_loss: 0.6438579   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.758344
# Learning rate = 0.0020000
# Epoch 19  X_rec_loss: 0.6417201   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7522412
# Learning rate = 0.0020000
# Epoch 20  X_rec_loss: 0.63995385   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7464239
# Learning rate = 0.0020000
# Epoch 21  X_rec_loss: 0.6386041   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7412009
# Learning rate = 0.0020000
# Epoch 22  X_rec_loss: 0.6373964   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.736442
# Learning rate = 0.0020000
# Epoch 23  X_rec_loss: 0.6359272   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7316338
# Learning rate = 0.0020000
# Epoch 24  X_rec_loss: 0.63472104   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.72718877
# Learning rate = 0.0016000
# Epoch 25  X_rec_loss: 0.63355005   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.72279894
# Learning rate = 0.0016000
# Epoch 26  X_rec_loss: 0.63260525   A_rec_loss: 0.00084617856   MNN_loss: 0.00084617856  total_loss:  0.7192129
# Learning rate = 0.0016000
# Epoch 27  X_rec_loss: 0.6317667   A_rec_loss: 0.0008461786   MNN_loss: 0.0008461786  total_loss:  0.7156882
# Learning rate = 0.0016000
# Epoch 28  X_rec_loss: 0.6308968   A_rec_loss: 0.0008461786   MNN_loss: 0.0008461786  total_loss:  0.7122553
# Learning rate = 0.0016000
# Epoch 29  X_rec_loss: 0.63006073   A_rec_loss: 0.0008461789   MNN_loss: 0.0008461789  total_loss:  0.70902246
# Learning rate = 0.0016000
# Epoch 30  X_rec_loss: 0.6292861   A_rec_loss: 0.0008461799   MNN_loss: 0.0008461799  total_loss:  0.7058917
# Learning rate = 0.0016000
# Epoch 31  X_rec_loss: 0.62846756   A_rec_loss: 0.0008461824   MNN_loss: 0.0008461824  total_loss:  0.7026957
# Learning rate = 0.0016000
# Epoch 32  X_rec_loss: 0.6276918   A_rec_loss: 0.00084618764   MNN_loss: 0.00084618764  total_loss:  0.6996151
# Learning rate = 0.0016000
# Epoch 33  X_rec_loss: 0.6269336   A_rec_loss: 0.0008461955   MNN_loss: 0.0008461955  total_loss:  0.69669807
# Learning rate = 0.0016000
# Epoch 34  X_rec_loss: 0.6261783   A_rec_loss: 0.0008462083   MNN_loss: 0.0008462083  total_loss:  0.6939022
# Learning rate = 0.0016000
# Epoch 35  X_rec_loss: 0.62546587   A_rec_loss: 0.0008462355   MNN_loss: 0.0008462355  total_loss:  0.6912303
# Learning rate = 0.0016000
# Epoch 36  X_rec_loss: 0.6247164   A_rec_loss: 0.00084628793   MNN_loss: 0.00084628793  total_loss:  0.6886074
# Learning rate = 0.0016000
# Epoch 37  X_rec_loss: 0.62397474   A_rec_loss: 0.0008463852   MNN_loss: 0.0008463852  total_loss:  0.6860786
# Learning rate = 0.0016000
# Epoch 38  X_rec_loss: 0.6232202   A_rec_loss: 0.0008465929   MNN_loss: 0.0008465929  total_loss:  0.6836327
# Learning rate = 0.0016000
# Epoch 39  X_rec_loss: 0.62249285   A_rec_loss: 0.0008470894   MNN_loss: 0.0008470894  total_loss:  0.6812992
# Learning rate = 0.0016000
# Epoch 40  X_rec_loss: 0.6218495   A_rec_loss: 0.0008482677   MNN_loss: 0.0008482677  total_loss:  0.67907846
# Learning rate = 0.0016000
# Epoch 41  X_rec_loss: 0.621238   A_rec_loss: 0.00085060974   MNN_loss: 0.00085060974  total_loss:  0.6769049
# Learning rate = 0.0016000
# Epoch 42  X_rec_loss: 0.6206563   A_rec_loss: 0.0008541189   MNN_loss: 0.0008541189  total_loss:  0.67483056
# Learning rate = 0.0016000
# Epoch 43  X_rec_loss: 0.6200436   A_rec_loss: 0.0008586432   MNN_loss: 0.0008586432  total_loss:  0.6728071
# Learning rate = 0.0016000
# Epoch 44  X_rec_loss: 0.6194368   A_rec_loss: 0.00086356886   MNN_loss: 0.00086356886  total_loss:  0.6708346
# Learning rate = 0.0016000
# Epoch 45  X_rec_loss: 0.61882156   A_rec_loss: 0.00086684985   MNN_loss: 0.00086684985  total_loss:  0.6688955
# Learning rate = 0.0016000
# Epoch 46  X_rec_loss: 0.6181846   A_rec_loss: 0.00086759194   MNN_loss: 0.00086759194  total_loss:  0.6670065
# Learning rate = 0.0016000
# Epoch 47  X_rec_loss: 0.61750454   A_rec_loss: 0.0008684041   MNN_loss: 0.0008684041  total_loss:  0.66515654
# Learning rate = 0.0016000
# Epoch 48  X_rec_loss: 0.6168161   A_rec_loss: 0.00087293016   MNN_loss: 0.00087293016  total_loss:  0.66335255
# Learning rate = 0.0016000
# Epoch 49  X_rec_loss: 0.61614317   A_rec_loss: 0.00088260334   MNN_loss: 0.00088260334  total_loss:  0.6615972
# Learning rate = 0.0012800
# Epoch 50  X_rec_loss: 0.6154506   A_rec_loss: 0.0008967413   MNN_loss: 0.0008967413  total_loss:  0.65989465
# Learning rate = 0.0012800
# Epoch 51  X_rec_loss: 0.61482495   A_rec_loss: 0.00091060344   MNN_loss: 0.00091060344  total_loss:  0.6585437
# Learning rate = 0.0012800
# Epoch 52  X_rec_loss: 0.6141538   A_rec_loss: 0.000926964   MNN_loss: 0.000926964  total_loss:  0.6572038
# Learning rate = 0.0012800
# Epoch 53  X_rec_loss: 0.61346906   A_rec_loss: 0.00094609   MNN_loss: 0.00094609  total_loss:  0.6558779
# Learning rate = 0.0012800
# Epoch 54  X_rec_loss: 0.61279166   A_rec_loss: 0.00096744136   MNN_loss: 0.00096744136  total_loss:  0.65458316
# Learning rate = 0.0012800
# Epoch 55  X_rec_loss: 0.61210537   A_rec_loss: 0.000991651   MNN_loss: 0.000991651  total_loss:  0.65330666
# Learning rate = 0.0012800
# Epoch 56  X_rec_loss: 0.61142206   A_rec_loss: 0.0010182017   MNN_loss: 0.0010182017  total_loss:  0.6520416
# Learning rate = 0.0012800
# Epoch 57  X_rec_loss: 0.6107451   A_rec_loss: 0.001043371   MNN_loss: 0.001043371  total_loss:  0.6507812
# Learning rate = 0.0012800
# Epoch 58  X_rec_loss: 0.6100427   A_rec_loss: 0.0010629862   MNN_loss: 0.0010629862  total_loss:  0.6495282
# Learning rate = 0.0012800
# Epoch 59  X_rec_loss: 0.60928226   A_rec_loss: 0.0010745162   MNN_loss: 0.0010745162  total_loss:  0.64827114
# Learning rate = 0.0012800
# Epoch 60  X_rec_loss: 0.6085035   A_rec_loss: 0.0010784252   MNN_loss: 0.0010784252  total_loss:  0.6470185
# Learning rate = 0.0012800
# Epoch 61  X_rec_loss: 0.6077333   A_rec_loss: 0.0010787776   MNN_loss: 0.0010787776  total_loss:  0.6457694
# Learning rate = 0.0012800
# Epoch 62  X_rec_loss: 0.6069381   A_rec_loss: 0.0010791023   MNN_loss: 0.0010791023  total_loss:  0.6445147
# Learning rate = 0.0012800
# Epoch 63  X_rec_loss: 0.6061167   A_rec_loss: 0.0010780992   MNN_loss: 0.0010780992  total_loss:  0.6432555
# Learning rate = 0.0012800
# Epoch 64  X_rec_loss: 0.6052864   A_rec_loss: 0.0010770021   MNN_loss: 0.0010770021  total_loss:  0.6419902
# Learning rate = 0.0012800
# Epoch 65  X_rec_loss: 0.6044319   A_rec_loss: 0.0010793436   MNN_loss: 0.0010793436  total_loss:  0.6407262
# Learning rate = 0.0012800
# Epoch 66  X_rec_loss: 0.60355705   A_rec_loss: 0.001081389   MNN_loss: 0.001081389  total_loss:  0.6394617
# Learning rate = 0.0012800
# Epoch 67  X_rec_loss: 0.6026537   A_rec_loss: 0.0010857332   MNN_loss: 0.0010857332  total_loss:  0.6381956
# Learning rate = 0.0012800
# Epoch 68  X_rec_loss: 0.6017487   A_rec_loss: 0.0010920408   MNN_loss: 0.0010920408  total_loss:  0.63693166
# Learning rate = 0.0012800
# Epoch 69  X_rec_loss: 0.6008418   A_rec_loss: 0.0010984987   MNN_loss: 0.0010984987  total_loss:  0.6356779
# Learning rate = 0.0012800
# Epoch 70  X_rec_loss: 0.59997964   A_rec_loss: 0.001104838   MNN_loss: 0.001104838  total_loss:  0.6344429
# Learning rate = 0.0012800
# Epoch 71  X_rec_loss: 0.59915143   A_rec_loss: 0.0011145964   MNN_loss: 0.0011145964  total_loss:  0.6332268
# Learning rate = 0.0012800
# Epoch 72  X_rec_loss: 0.5983533   A_rec_loss: 0.0011231224   MNN_loss: 0.0011231224  total_loss:  0.6320531
# Learning rate = 0.0012800
# Epoch 73  X_rec_loss: 0.59783816   A_rec_loss: 0.0011377967   MNN_loss: 0.0011377967  total_loss:  0.631262
# Learning rate = 0.0012800
# Epoch 74  X_rec_loss: 0.6023205   A_rec_loss: 0.0011335387   MNN_loss: 0.0011335387  total_loss:  0.63526905
# Learning rate = 0.0010240
# Epoch 75  X_rec_loss: 0.61464274   A_rec_loss: 0.0012562817   MNN_loss: 0.0012562817  total_loss:  0.6483453
# Learning rate = 0.0010240
# Early stopping...
# train Finish!
# peak memory: 4251.97 MiB, increment: 2180.77 MiB
# time used: 267.0209548473358

# %%
import anndata as ad
adata_scGAMNN=ad.AnnData(model.embedding(scaledata, adj_n))
sc.pp.neighbors(adata_scGAMNN)
sc.tl.umap(adata_scGAMNN)
adata_scGAMNN.obs['celltype'] = adata.obs['celltype'].to_list()
adata_scGAMNN.obs['batch'] = ['mouse' if i == 0 else 'human' for i in adata.obs['batch']]
sc.pl.umap(adata_scGAMNN, color='batch')
sc.pl.umap(adata_scGAMNN, color='celltype')
# Out:
# computing neighbors
#     using data matrix X directly
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:04:54)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:15)

# %%
inte_scGAMNN=integrate_indicators (np.array(adata_scGAMNN.obsm['X_umap']),np.array(adata_scGAMNN.obs['batch']),np.array(adata_scGAMNN.obs['celltype']))
inte_scGAMNN_df=pd.DataFrame.from_dict(inte_scGAMNN,orient='index').T
# Out:
# integrate ASW_c: 0.7727 ASW_b: 0.7790

# %%
#8-------------------------
sc.tl.leiden(adata_scGAMNN,resolution=0.1)
cluster_scGAMNN=cluster_indicators (adata_scGAMNN.obs['leiden'],np.array(adata_scGAMNN.obs['celltype']))
cluster_scGAMNN_df=pd.DataFrame.from_dict(cluster_scGAMNN,orient='index').T
# Out:
# running Leiden clustering
#     finished: found 9 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)
# cluster nmi: 0.9191 ari: 0.9489

# %%
sc.pl.umap(adata_scGAMNN,color='batch',save='_mh1_scGAMNN_batch.pdf')
sc.pl.umap(adata_scGAMNN,color='celltype',save='_mh1_scGAMNN_celltype.pdf')
# Out:
# WARNING: saving figure to file figures\umap_mh1_scGAMNN_batch.pdf
# WARNING: saving figure to file figures\umap_mh1_scGAMNN_celltype.pdf

# %%
inte_scGAMNN_df.to_csv('result/inte_scGAMNN_mh1.csv',index=0)
cluster_scGAMNN_df.to_csv('result/c_scGAMNN_mh1.csv',index=0)

# %%
adata_scGAMNN.write('result/adata_scGAMNN_mh1.h5ad')
#adata_scGAMNN= sc.read_h5ad('result/adata_scGAMNN_mh.h5ad')

# %%
entropy_scGAMNN=compute_entropy(adata_scGAMNN)
entropy_scGAMNN.to_csv('result/entropy_scGAMNN_mh1.csv',index=0)
# Out:
# Calculating entropy ...
# use exist neighbors
# Entropy calculated!
